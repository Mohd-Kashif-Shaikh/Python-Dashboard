# %%
import pandas as pd
import numpy as np 
import panel as pn
pn.extension('tabulator')
import hvplot.pandas
import holoviews as hv
hv.extension('bokeh')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='9df512d4-7c5e-4465-a4ff-37a02d03db5e'>
#   <div id="dfd88e03-2f12-4864-88c7-29396eeaab1a" data-root-id="9df512d4-7c5e-4465-a4ff-37a02d03db5e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"1c5d59a4-b444-48d2-babe-8796709429b0":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"9df512d4-7c5e-4465-a4ff-37a02d03db5e"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"8817fc17-e1cd-47ad-bbd7-2e3068ef73d3","attributes":{"plot_id":"9df512d4-7c5e-4465-a4ff-37a02d03db5e","comm_id":"97155c2c40e84822872003229835d876","client_comm_id":"2654db628b7246268b327e8a5f43b8a6"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"1c5d59a4-b444-48d2-babe-8796709429b0","roots":{"9df512d4-7c5e-4465-a4ff-37a02d03db5e":"dfd88e03-2f12-4864-88c7-29396eeaab1a"},"root_ids":["9df512d4-7c5e-4465-a4ff-37a02d03db5e"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %% [markdown]
# # Loading / Reading  the dataset

# %%
df=pd.read_csv("transactions.csv")

# %%
df.head()
# Out:
#            Type  Product           Start Date             End Date  \
# 0  CARD_PAYMENT  Current  2023-01-26 22:02:47  2023-01-27 10:10:12
# 1  CARD_PAYMENT  Current  2023-01-26 16:13:50  2023-01-27 11:50:32
# 2  CARD_PAYMENT  Current  2023-01-26 08:26:35  2023-01-27 13:42:55
# 3  CARD_PAYMENT  Current  2023-01-27 13:16:59  2023-01-28 09:59:20
# 4  CARD_PAYMENT  Current  2023-01-27 10:43:22  2023-01-28 11:48:36
#
#               Description  Amount  Fee Currency      State  Balance
# 0       Tesco Stores 6601   -6.35  0.0      GBP  COMPLETED   521.07
# 1  Zettle_*donovan?s Bake   -2.50  0.0      GBP  COMPLETED   518.57
# 2          apple.com/bill   -3.99  0.0      GBP  COMPLETED   514.58
# 3       Tesco Stores 6601   -4.85  0.0      GBP  COMPLETED   509.73
# 4  Zettle_*the Good Eatin   -3.30  0.0      GBP  COMPLETED   506.43

# %%
df.isnull().sum()
# Out:
# Type           0
# Product        0
# Start Date     0
# End Date       0
# Description    0
# Amount         0
# Fee            0
# Currency       0
# State          0
# Balance        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Type         81 non-null     object
#  1   Product      81 non-null     object
#  2   Start Date   81 non-null     object
#  3   End Date     81 non-null     object
#  4   Description  81 non-null     object
#  5   Amount       81 non-null     float64
#  6   Fee          81 non-null     float64
#  7   Currency     81 non-null     object
#  8   State        81 non-null     object
#  9   Balance      81 non-null     float64
# dtypes: float64(3), object(7)
# memory usage: 6.5+ KB

# %% [markdown]
# # Cleaning the Data

# %%
df["Description"]=df["Description"].map(str.lower)

# %%
df.head()
# Out:
#            Type  Product           Start Date             End Date  \
# 0  CARD_PAYMENT  Current  2023-01-26 22:02:47  2023-01-27 10:10:12
# 1  CARD_PAYMENT  Current  2023-01-26 16:13:50  2023-01-27 11:50:32
# 2  CARD_PAYMENT  Current  2023-01-26 08:26:35  2023-01-27 13:42:55
# 3  CARD_PAYMENT  Current  2023-01-27 13:16:59  2023-01-28 09:59:20
# 4  CARD_PAYMENT  Current  2023-01-27 10:43:22  2023-01-28 11:48:36
#
#               Description  Amount  Fee Currency      State  Balance
# 0       tesco stores 6601   -6.35  0.0      GBP  COMPLETED   521.07
# 1  zettle_*donovan?s bake   -2.50  0.0      GBP  COMPLETED   518.57
# 2          apple.com/bill   -3.99  0.0      GBP  COMPLETED   514.58
# 3       tesco stores 6601   -4.85  0.0      GBP  COMPLETED   509.73
# 4  zettle_*the good eatin   -3.30  0.0      GBP  COMPLETED   506.43

# %%
df=df[["End Date","Description","Amount"]]

# %%
df=df.rename(columns={"End Date":"Date"})

# %%
df['Category'] = 'unassigned' 
df.head()
# Out:
#                   Date             Description  Amount    Category
# 0  2023-01-27 10:10:12       tesco stores 6601   -6.35  unassigned
# 1  2023-01-27 11:50:32  zettle_*donovan?s bake   -2.50  unassigned
# 2  2023-01-27 13:42:55          apple.com/bill   -3.99  unassigned
# 3  2023-01-28 09:59:20       tesco stores 6601   -4.85  unassigned
# 4  2023-01-28 11:48:36  zettle_*the good eatin   -3.30  unassigned

# %%
df["Description"]
# Out:
# 0          tesco stores 6601
# 1     zettle_*donovan?s bake
# 2             apple.com/bill
# 3          tesco stores 6601
# 4     zettle_*the good eatin
#                ...
# 76            restaurant pqr
# 77     electronics store mno
# 78           gas station abc
# 79                  cafe xyz
# 80            restaurant def
# Name: Description, Length: 81, dtype: object

# %% [markdown]
#  Assinging Transcations to the Category

# %%
df['Category'] = np.where(df['Description'].str.contains(
    'cash at tesco old st h exp|gym membership|pharmacy xyz|boots|royal'), 
    'Personal Care', df['Category'] )
    
    
df['Category'] = np.where(df['Description'].str.contains(
    'car rental'), 
    'Penalties', df['Category'] )
    


df['Category'] = np.where(df['Description'].str.contains(
    'lavelle|coffee shop|hart|starbucks|barista|new road|mama shelter'), 
    'Coffee', df['Category'] )
    
    
df['Category'] = np.where(df['Description'].str.contains(
    'islington|hardware store|gas station abc|electronics store mno|at camden town'), 
    'Retail', df['Category'] )
    


df['Category'] = np.where(df['Description'].str.contains(
    'bakehouse|cafe|zettle|caravan|kod|eating|o ver|mcdonald|manteca|wine house|giacomo|real greek|restaurant|katsute|tonkotsu|zia lucia|viet|change please|me zhi chua|osm'), 
    'Dining', df['Category'] )
        

    
df['Category'] = np.where(df['Description'].str.contains(
    'montys|urban|oshveda|egg|francesco|budgens whitechapel'), 
    'Entertainment', df['Category'] )
    

df['Category'] = np.where(df['Description'].str.contains(
    'gucci|blomma'), 
    'Gifts', df['Category'] )
    

    
df['Category'] = np.where(df['Description'].str.contains(
    'apple|snappy|exchanged to usd'), 
    'Services', df['Category'] )
    
    
df['Category'] = np.where(df['Description'].str.contains(
    'from|paypal|amznmktplace|starnow|refund|giffgaff|backstage|hectagon|tower hamlets bc|sweet suites|temporary hold|cm.com'), 
    'Not Categorized', df['Category'] )


df['Category'] = np.where(df['Description'].str.contains(
    'tesco|grocery store|sainsbury|asda|lidl|toogoodtog|nisa|market|millennium mini store'), 
    'Groceries', df['Category'] )


    
df['Category'] = np.where(df['Description'].str.contains(
    'uber|zipcar|bird|tfl|Ewa'), 
    'Transportation', df['Category'] )
    

    
df['Category'] = np.where(df['Description'].str.contains(
    'ryanair|movie theater|easyjet|airways'), 
    'Vacation', df['Category'] )


df['Category'] = np.where(df['Description'].str.contains(
    'tubebuddy|itunes|dario|calendly|canva|epidemic|upwork|lada'), 
    'Miscellaneous', df['Category'] )

# %%
df.head()
# Out:
#                   Date             Description  Amount   Category
# 0  2023-01-27 10:10:12       tesco stores 6601   -6.35  Groceries
# 1  2023-01-27 11:50:32  zettle_*donovan?s bake   -2.50     Dining
# 2  2023-01-27 13:42:55          apple.com/bill   -3.99   Services
# 3  2023-01-28 09:59:20       tesco stores 6601   -4.85  Groceries
# 4  2023-01-28 11:48:36  zettle_*the good eatin   -3.30     Dining

# %%
unassigned = df.loc[df['Category'] == 'unassigned']
unassigned
# Out:
# Empty DataFrame
# Columns: [Date, Description, Amount, Category]
# Index: []

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
df.head()
# Out:
#                  Date             Description  Amount   Category
# 0 2023-01-27 10:10:12       tesco stores 6601   -6.35  Groceries
# 1 2023-01-27 11:50:32  zettle_*donovan?s bake   -2.50     Dining
# 2 2023-01-27 13:42:55          apple.com/bill   -3.99   Services
# 3 2023-01-28 09:59:20       tesco stores 6601   -4.85  Groceries
# 4 2023-01-28 11:48:36  zettle_*the good eatin   -3.30     Dining

# %%
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year

# %%
df.head()
# Out:
#                  Date             Description  Amount   Category  Month  Year
# 0 2023-01-27 10:10:12       tesco stores 6601   -6.35  Groceries      1  2023
# 1 2023-01-27 11:50:32  zettle_*donovan?s bake   -2.50     Dining      1  2023
# 2 2023-01-27 13:42:55          apple.com/bill   -3.99   Services      1  2023
# 3 2023-01-28 09:59:20       tesco stores 6601   -4.85  Groceries      1  2023
# 4 2023-01-28 11:48:36  zettle_*the good eatin   -3.30     Dining      1  2023

# %%
latest_month=df["Month"].max()
latest_year=df["Year"].max()

# %%
last_month_expenses=df[(df['Month'] == latest_month) & (df['Year'] == latest_year)]
last_month_expenses.head()
# Out:
#                   Date        Description  Amount       Category  Month  Year
# 63 2023-03-03 14:45:45    gas station abc  -14.25         Retail      3  2023
# 64 2023-03-03 20:30:25    coffee shop abc   -7.95         Coffee      3  2023
# 65 2023-03-04 15:50:35  grocery store def  -28.50      Groceries      3  2023
# 66 2023-03-04 20:20:25       pharmacy xyz  -15.95  Personal Care      3  2023
# 67 2023-03-05 15:30:30     restaurant pqr  -19.99         Dining      3  2023

# %%
last_month_expenses = last_month_expenses.groupby('Category')['Amount'].sum().reset_index()
last_month_expenses
# Out:
#         Category  Amount
# 0         Coffee  -15.90
# 1         Dining -126.48
# 2      Groceries  -57.00
# 3  Personal Care  -31.90
# 4         Retail  -74.50

# %%
last_month_expenses['Amount']=last_month_expenses['Amount'].astype('str')

# %%
last_month_expenses['Amount']=last_month_expenses['Amount'].str.replace('-','')
last_month_expenses
# Out:
#         Category              Amount
# 0         Coffee                15.9
# 1         Dining  126.47999999999999
# 2      Groceries                57.0
# 3  Personal Care                31.9
# 4         Retail                74.5

# %%
last_month_expenses['Amount']=last_month_expenses['Amount'].astype('float')   
last_month_expenses
# Out:
#         Category  Amount
# 0         Coffee   15.90
# 1         Dining  126.48
# 2      Groceries   57.00
# 3  Personal Care   31.90
# 4         Retail   74.50

# %%
last_month_expenses = last_month_expenses[last_month_expenses["Category"].str.contains("Not Categorized|unassigned") == False]  
last_month_expenses = last_month_expenses.sort_values(by='Amount', ascending=False)  
last_month_expenses['Amount'] = last_month_expenses['Amount'].round().astype(int)

# %%
last_month_expenses
# Out:
#         Category  Amount
# 1         Dining     126
# 4         Retail      74
# 2      Groceries      57
# 3  Personal Care      32
# 0         Coffee      16

# %%
last_month_expenses_total = last_month_expenses['Amount'].sum()
last_month_expenses_total
# Out:
# 305

# %%
def calculate_difference(event):
    income = float(income_widget.value)
    recurring_expenses = float(recurring_expenses_widget.value)
    monthly_expenses = float(monthly_expenses_widget.value)
    difference = income - recurring_expenses - monthly_expenses
    difference_widget.value = str(difference)
income_widget = pn.widgets.TextInput(name="Income", value="0")
recurring_expenses_widget = pn.widgets.TextInput(name="Recurring Expenses", value="0")
monthly_expenses_widget = pn.widgets.TextInput(name="Non-Recurring Expenses", value=str(last_month_expenses_total))
difference_widget = pn.widgets.TextInput(name="Last Month's Savings", value="0")

income_widget.param.watch(calculate_difference, "value")
recurring_expenses_widget.param.watch(calculate_difference, "value")
monthly_expenses_widget.param.watch(calculate_difference, "value")
# Out:
# Watcher(inst=TextInput(name='Non-Recurring Expenses', value='305'), cls=<class 'panel.widgets.input.TextInput'>, fn=<function calculate_difference at 0x00000173B6F6A1F0>, mode='args', onlychanged=True, parameter_names=('value',), what='value', queued=False, precedence=0)

# %%
#pn.Row(income_widget, recurring_expenses_widget, monthly_expenses_widget, difference_widget).show()

# %%
last_month_expenses
# Out:
#         Category  Amount
# 1         Dining     126
# 4         Retail      74
# 2      Groceries      57
# 3  Personal Care      32
# 0         Coffee      16

# %% [markdown]
# # Visualizing the data

# %% [markdown]
# Bar Graph

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
last_month_expenses_chart = last_month_expenses.hvplot.bar(
    x='Category', 
    y='Amount', 
    height=250, 
    width=850, 
    title="Last Month Expenses",
    ylim=(0, 500))

last_month_expenses_chart
# Out:
# :Bars   [Category]   (Amount)

# %%
#last_month_expenses_chart=sns.barplot(x="Category",y="Amount",data=last_month_expenses)
#plt.title("Last_Month_Expenses")
#plt.show()
#last_month_expenses_chart

# %%
df['Date'] = pd.to_datetime(df['Date'])            
df['Month-Year'] = df['Date'].dt.to_period('M')    
monthly_expenses_trend_by_cat = df.groupby(['Month-Year', 'Category'])['Amount'].sum().reset_index()

# %%
monthly_expenses_trend_by_cat['Amount']=monthly_expenses_trend_by_cat['Amount'].astype('str')
monthly_expenses_trend_by_cat['Amount']=monthly_expenses_trend_by_cat['Amount'].str.replace('-','')
monthly_expenses_trend_by_cat['Amount']=monthly_expenses_trend_by_cat['Amount'].astype('float')
monthly_expenses_trend_by_cat = monthly_expenses_trend_by_cat[monthly_expenses_trend_by_cat["Category"].str.contains("Not Categorized") == False]

# %%
monthly_expenses_trend_by_cat = monthly_expenses_trend_by_cat.sort_values(by='Amount', ascending=False)
monthly_expenses_trend_by_cat['Amount'] = monthly_expenses_trend_by_cat['Amount'].round().astype(int)
monthly_expenses_trend_by_cat['Month-Year'] = monthly_expenses_trend_by_cat['Month-Year'].astype(str)
monthly_expenses_trend_by_cat = monthly_expenses_trend_by_cat.rename(columns={'Amount': 'Amount '})

# %%
monthly_expenses_trend_by_cat
# Out:
#    Month-Year        Category  Amount
# 10    2023-02          Dining      143
# 18    2023-03          Dining      126
# 11    2023-02       Groceries      124
# 14    2023-02          Retail       95
# 21    2023-03          Retail       74
# 16    2023-02        Vacation       62
# 19    2023-03       Groceries       57
# 9     2023-02          Coffee       54
# 1     2023-01          Dining       46
# 2     2023-01   Entertainment       40
# 4     2023-01       Groceries       37
# 3     2023-01           Gifts       35
# 20    2023-03   Personal Care       32
# 13    2023-02   Personal Care       25
# 8     2023-01  Transportation       24
# 15    2023-02  Transportation       23
# 17    2023-03          Coffee       16
# 0     2023-01          Coffee        7
# 7     2023-01        Services        4
# 5     2023-01   Miscellaneous        2

# %%
select_category1 = pn.widgets.Select(name='Select Category', options=[
    'All',
    'Personal Care',
    'Penalties',
    'Miscellaneous',
    'Coffee',
    'Groceries',
    'Retail',
    'Dining',
    'Transportation',
    'Vacation',
    'Entertainment',
    'Gifts',
    'Services',
    'Entertainment',
])

select_category1
# Out:
# Select(options=['All', 'Personal Care', ...], value='All')

# %%
def plot_expenses(category):
    if category == 'All':
        plot_df = monthly_expenses_trend_by_cat.groupby('Month-Year').sum()
    else:
        plot_df = monthly_expenses_trend_by_cat[monthly_expenses_trend_by_cat['Category'] == category].groupby('Month-Year').sum()
    plot = plot_df.hvplot.bar(x='Month-Year', y='Amount ')
    return plot

# %%
@pn.depends(select_category1.param.value)
def update_plot(category):
    plot = plot_expenses(category)
    return plot

# %%
monthly_expenses_trend_by_cat_chart = pn.Row(select_category1, update_plot)
monthly_expenses_trend_by_cat_chart[1].width = 600

monthly_expenses_trend_by_cat_chart
# Out:
# Row
#     [0] Select(options=['All', 'Personal Care', ...], value='All')
#     [1] ParamFunction(function, _pane=HoloViews, defer_load=False, width=600)

# %%
df = df[['Date', 'Category', 'Description', 'Amount']]
df['Amount']=df['Amount'].astype('str')
df['Amount']=df['Amount'].str.replace('-','')
df['Amount']=df['Amount'].astype('float')       
df = df[df["Category"].str.contains("Not Categorized") == False]   
df['Amount'] = df['Amount'].round().astype(int)      
df
# Out:
#                   Date   Category             Description  Amount
# 0  2023-01-27 10:10:12  Groceries       tesco stores 6601       6
# 1  2023-01-27 11:50:32     Dining  zettle_*donovan?s bake       2
# 2  2023-01-27 13:42:55   Services          apple.com/bill       4
# 3  2023-01-28 09:59:20  Groceries       tesco stores 6601       5
# 4  2023-01-28 11:48:36     Dining  zettle_*the good eatin       3
# ..                 ...        ...                     ...     ...
# 76 2023-03-10 15:30:30     Dining          restaurant pqr      20
# 77 2023-03-10 20:55:40     Retail   electronics store mno      13
# 78 2023-03-11 14:20:45     Retail         gas station abc      10
# 79 2023-03-11 19:25:35     Dining                cafe xyz      18
# 80 2023-03-12 20:10:25     Dining          restaurant def      25
#
# [78 rows x 4 columns]

# %%
def filter_df(category):
    if category == 'All':
        return df
    return df[df['Category'] == category]

# %%
summary_table = pn.widgets.DataFrame(filter_df('All'), height = 300,width=400)

# %%
def update_summary_table(event):
    summary_table.value = filter_df(event.new)

# %%
select_category1.param.watch(update_summary_table, 'value')
summary_table
# Out:
# DataFrame(height=300, sizing_mode='fixed', value=              ..., width=400)

# %%
template = pn.template.FastListTemplate(
    title="Personal Finances Summary",
    sidebar=[
        pn.pane.Markdown("## Financial success starts with smart money management "),
        pn.pane.PNG('https://www.vhv.rs/dpng/d/282-2820575_dollar-vector-png-money-vectors-transparent-png.png', sizing_mode='scale_both'),
        pn.pane.Markdown(""),
        pn.pane.Markdown(""),
        select_category1
    ],
    main=[
        pn.Row(income_widget, recurring_expenses_widget, monthly_expenses_widget, difference_widget, width=950),
        pn.Row(last_month_expenses_chart, height=240),
        pn.GridBox(
            monthly_expenses_trend_by_cat_chart[1],
            summary_table,
            ncols=2,
            width=500,  
            align='start',
            sizing_mode='stretch_width'
        )
    ]
)

template.show()
template.servable();
# Out:
# WARNING:param.GridBox: Providing a width-responsive sizing_mode ('stretch_width') and a fixed width is not supported. Converting fixed width to min_width. If you intended the component to be fully width-responsive remove the heightsetting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# Launching server at http://localhost:52796
